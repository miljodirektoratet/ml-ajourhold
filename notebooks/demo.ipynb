# %% [markdown]
# # ml-ajourhold Demo Notebook
#
# This notebook demonstrates how to use the ml-ajourhold package.
#
# ## Prerequisites
#
# Make sure you have:
# 1. Completed the setup from the [setup guide](../docs/setup-guide.md)
# 2. Selected the correct kernel (`.venv` environment)
# 3. Installed the package in development mode: `uv sync --group dev`
#
# ## Basic Usage

# %%
# Test imports for local package and GPU stack
import ml_ajourhold
import torch

print(torch.__version__)
print("CUDA:", torch.cuda.is_available())

# %%
# Check the package version
print(f"Package version: {ml_ajourhold.__version__}")

# %%
# Run the main entrypoint function
ml_ajourhold.main()
